# %% [markdown]
# # Colab Intro & Setup Check — Solutions
#
# <a target="_blank" href="https://colab.research.google.com/github/LuWidme/uk259/blob/rework/solutions/01_Colab_Intro_and_Setup_Check_solutions.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# > ~30 min · Day 1
#
# **Important:** Try the exercises in `demos/01_Colab_Intro_and_Setup_Check.ipynb` yourself first. The struggle is where the learning happens.
#
# These are *reference* solutions with short explanations. Your own working solution may look different and still be correct.

# %% [markdown]
# ### Exercise 1: Edit a cell

# %%
name = "Alex"   # put any name in quotes

print(f"Hello, {name}! Welcome to the course.")

# %% [markdown]
# ### Exercise 2: Variables and calculation

# %%
price = 18.50
tickets = 4

total = price * tickets   # multiply price by number of tickets

print(f"{tickets} tickets cost CHF {total}")

# %% [markdown]
# ### Exercise 3: A loop
#
# `range(1, 6)` produces 1, 2, 3, 4, 5 (the stop value is excluded).

# %%
for n in range(1, 6):
    print(n)
