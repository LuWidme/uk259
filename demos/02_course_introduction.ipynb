# %% [markdown]
# # Course Introduction: Python for Machine Learning
#
# Welcome to üK 259 Machine Learning! This notebook introduces the core Python libraries you'll use throughout the course.
#
# ## About Jupyter Notebooks
#
# Jupyter Notebooks consist of two types of cells:
#
# * **Text cells** (markdown) - Contain explanations like this one
# * **Code cells** - Contain Python code you can execute
#
# **To run a code cell:**
# 1. Click on the cell
# 2. Press `Shift + Enter` or click the Run button
#
# **Important:** Run code cells in order from top to bottom!

# %% [markdown]
# ---
# ## Part 1: NumPy - Numerical Python
#
# NumPy is the foundation for scientific computing in Python. It provides:
# - Fast operations on arrays and matrices
# - Mathematical functions
# - Random number generation

# %%
# Import NumPy (standard alias: np)
import numpy as np

# %% [markdown]
# ### Creating Arrays
#
# Arrays are the fundamental data structure in NumPy.

# %%
# 1D array (vector)
vector = np.array([1.2, 2.4, 3.5, 4.7, 6.1])
print("1D array:")
print(vector)

# %%
# 2D array (matrix)
matrix = np.array([[6, 5], [11, 7], [4, 8]])
print("2D array:")
print(matrix)
print(f"\nShape: {matrix.shape}")  # (rows, columns)

# %% [markdown]
# ### Generating Arrays

# %%
# Sequence of numbers (like Python's range)
sequence = np.arange(5, 12)  # start (inclusive) to stop (exclusive)
print("Sequence:", sequence)

# %%
# Arrays of zeros and ones
zeros = np.zeros(5)
ones = np.ones((3, 4))  # 3x4 matrix of ones
print("Zeros:", zeros)
print("\nOnes:\n", ones)

# %% [markdown]
# ### Random Numbers

# %%
# Random integers
random_ints = np.random.randint(low=50, high=101, size=6)
print("Random integers [50-100]:", random_ints)

# %%
# Random floats [0.0, 1.0)
random_floats = np.random.random(6)
print("Random floats [0-1]:", random_floats)

# %% [markdown]
# ### Mathematical Operations
#
# NumPy uses **broadcasting** to apply operations to entire arrays efficiently.

# %%
# Add a constant to all elements
data = np.array([1, 2, 3, 4, 5])
result = data + 10
print("Original:", data)
print("After +10:", result)

# %%
# Multiply all elements
result = data * 3
print("After *3:", result)

# %%
# Element-wise operations between arrays
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print("a + b =", a + b)
print("a * b =", a * b)

# %% [markdown]
# ---
# ## NumPy Exercises
#
# Now it's your turn! Complete the following tasks.

# %% [markdown]
# ### Task 1: Create a Linear Dataset
#
# Create two arrays:
# 1. `feature`: integers from 6 to 20 (inclusive) using `np.arange()`
# 2. `label`: calculated as `label = 3 * feature + 4`
#
# **Hint:** Remember that `np.arange(start, stop)` is exclusive of the stop value.

# %%
# Task 1: Write your code here
feature = ?  # Create array from 6 to 20 (inclusive)
label = ?    # Calculate: 3 * feature + 4

print("Feature:", feature)
print("Label:", label)

# %% [markdown]
# ### Task 2: Add Noise to the Dataset
#
# To make your dataset more realistic, add random noise:
#
# 1. Create a `noise` array with the same shape as `label`
# 2. Fill it with random floating-point values between -2 and +2
# 3. Add the noise to your `label` array to create `noisy_label`
#
# **Hints:**
# - Use `np.random.random()` to generate values between 0 and 1
# - Scale and shift these values to get the range [-2, +2]
# - Formula: `random_value * range + minimum`

# %%
# Task 2: Write your code here
noise = ?           # Create noise array between -2 and +2
noisy_label = ?     # Add noise to label

print("Original label:", label)
print("Noise:", noise)
print("Noisy label:", noisy_label)

# %% [markdown]
# ### Task 3: Array Statistics
#
# NumPy provides functions to calculate statistics. Calculate the following for the `noisy_label` array:
#
# 1. Mean (average) value
# 2. Maximum value
# 3. Minimum value
# 4. Standard deviation
#
# **Hints:** Use `np.mean()`, `np.max()`, `np.min()`, and `np.std()`

# %%
# Task 3: Write your code here
mean_value = ?       # Calculate mean
max_value = ?        # Calculate maximum
min_value = ?        # Calculate minimum
std_value = ?        # Calculate standard deviation

print(f"Mean: {mean_value}")
print(f"Max: {max_value}")
print(f"Min: {min_value}")
print(f"Std: {std_value}")

# %% [markdown]
# ### Task 4: Create a 2D Array
#
# Create a 4x5 matrix (4 rows, 5 columns) filled with:
# 1. All zeros - store in `zeros_matrix`
# 2. All ones - store in `ones_matrix`
# 3. Random integers between 10 and 50 - store in `random_matrix`
#
# Then print the shape of each matrix to verify.
#
# **Hints:** Use `np.zeros()`, `np.ones()`, and `np.random.randint()`

# %%
# Task 4: Write your code here
zeros_matrix = ?     # 4x5 matrix of zeros
ones_matrix = ?      # 4x5 matrix of ones
random_matrix = ?    # 4x5 matrix of random integers [10-50]

print("Zeros shape:", zeros_matrix.shape)
print("Ones shape:", ones_matrix.shape)
print("Random matrix:\n", random_matrix)

# %% [markdown]
# ### Task 5: Array Reshaping
#
# Create an array with values from 1 to 12 (inclusive) and reshape it into a 3x4 matrix.
#
# **Hints:**
# - Use `np.arange()` to create the sequence
# - Use `.reshape()` method to change the shape
# - The total number of elements must stay the same (12 = 3 × 4)

# %%
# Task 5: Write your code here
sequence = ?         # Create array [1, 2, 3, ..., 12]
reshaped = ?         # Reshape to 3x4 matrix

print("Original:", sequence)
print("\nReshaped (3x4):\n", reshaped)

# %% [markdown]
# ---
# ## Part 2: Pandas - Data Analysis
#
# Pandas is built on top of NumPy and provides:
# - DataFrames (like spreadsheets)
# - Easy data manipulation
# - File I/O (CSV, Excel, etc.)

# %%
# Import Pandas (standard alias: pd)
import pandas as pd

# %% [markdown]
# ### Creating DataFrames
#
# A DataFrame is a 2D labeled data structure with columns of potentially different types.

# %%
# From a NumPy array with column names
df = pd.DataFrame(
    np.random.randn(6, 4),  # 6 rows, 4 columns of random numbers
    columns=['A', 'B', 'C', 'D']
)
print("Sample DataFrame:")
df

# %%
# From a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'Paris', 'London', 'Tokyo']
}
people = pd.DataFrame(data)
people

# %% [markdown]
# ### Viewing Data

# %%
# First few rows
print("First 3 rows:")
df.head(3)

# %%
# Last few rows
print("Last 2 rows:")
df.tail(2)

# %%
# Summary statistics
df.describe()

# %%
# Data types of columns
df.dtypes

# %% [markdown]
# ### Selecting Data

# %%
# Select a single column (returns a Series)
print("Column A:")
print(df['A'])

# %%
# Select by position (iloc)
print("Rows 1-2, Columns 0-1:")
df.iloc[1:3, 0:2]

# %%
# Boolean indexing (filter rows)
print("Rows where column A > 0:")
df[df['A'] > 0]

# %% [markdown]
# ### Sorting

# %%
# Sort by a column
df.sort_values(by='B', ascending=False)

# %% [markdown]
# ### Working with Real Data

# %%
# Load a CSV file (one of our course datasets)
titanic = pd.read_csv('../datasets/titanic.csv')

print(f"Shape: {titanic.shape}")  # (rows, columns)
print(f"\nColumns: {list(titanic.columns)}")
print("\nFirst few rows:")
titanic.head()

# %%
# Get basic statistics
titanic.describe()

# %%
# Count how many people survived
print("Survival counts:")
print(titanic['Survived'].value_counts())

# %% [markdown]
# ---
# ## Pandas Exercises
#
# Now practice your Pandas skills with these tasks using the Titanic dataset.

# %% [markdown]
# ### Task 6: Filter by Gender
#
# Create two new DataFrames:
# 1. `female_passengers`: only female passengers
# 2. `male_passengers`: only male passengers
#
# Then print how many passengers are in each group.
#
# **Hint:** Use boolean indexing like `df[df['column'] == value]`

# %%
# Task 6: Write your code here
female_passengers = ?    # Filter for Sex == 'female'
male_passengers = ?      # Filter for Sex == 'male'

print(f"Female passengers: {len(female_passengers)}")
print(f"Male passengers: {len(male_passengers)}")

# %% [markdown]
# ### Task 7: Calculate Survival Rate by Gender
#
# Calculate the percentage of survivors for each gender:
# 1. For female passengers, calculate: (number who survived / total females) × 100
# 2. For male passengers, calculate: (number who survived / total males) × 100
#
# **Hints:**
# - Use `.sum()` on the 'Survived' column to count survivors (1 = survived, 0 = died)
# - Use `len()` to get total number of passengers

# %%
# Task 7: Write your code here
female_survival_rate = ?    # Calculate percentage
male_survival_rate = ?      # Calculate percentage

print(f"Female survival rate: {female_survival_rate:.1f}%")
print(f"Male survival rate: {male_survival_rate:.1f}%")

# %% [markdown]
# ### Task 8: Create a New Column
#
# Create a new column called 'Family_Size' that combines:
# - 'Siblings/Spouses Aboard'
# - 'Parents/Children Aboard'
# - Plus 1 (for the passenger themselves)
#
# Then display the first 10 rows showing Name, Family_Size, and Survived.
#
# **Hint:** You can create a new column with: `df['new_column'] = calculation`

# %%
# Task 8: Write your code here
titanic['Family_Size'] = ?    # Sum the family members + 1

# Display result
titanic[['Name', 'Family_Size', 'Survived']].head(10)

# %% [markdown]
# ### Task 9: Find the Most Expensive Ticket
#
# Find information about the passenger(s) who paid the highest fare:
# 1. Find the maximum fare value
# 2. Filter the DataFrame to show only rows where Fare equals this maximum
# 3. Display the Name, Pclass, and Fare columns
#
# **Hints:**
# - Use `.max()` to find the maximum value
# - Use boolean indexing to filter

# %%
# Task 9: Write your code here
max_fare = ?                      # Find maximum fare
most_expensive = ?                # Filter for rows with max fare

print(f"Maximum fare: ${max_fare:.2f}")
print("\nPassenger(s) with most expensive ticket:")
most_expensive[['Name', 'Pclass', 'Fare']]

# %% [markdown]
# ### Task 10: Group by Class and Calculate Average Age
#
# Calculate the average age for each passenger class (Pclass):
# 1. Group the data by 'Pclass'
# 2. Calculate the mean of 'Age' for each group
#
# **Hint:** Use `.groupby('column')['other_column'].mean()`

# %%
# Task 10: Write your code here
average_age_by_class = ?    # Group by Pclass and calculate mean Age

print("Average age by passenger class:")
print(average_age_by_class)

# %% [markdown]
# ### Task 11: Multiple Conditions Filter
#
# Create a DataFrame of passengers who meet ALL these conditions:
# - Female
# - First class (Pclass == 1)
# - Age less than 30
#
# Count how many passengers meet these criteria.
#
# **Hint:** Combine conditions with `&` (and): `df[(condition1) & (condition2) & (condition3)]`

# %%
# Task 11: Write your code here
filtered_passengers = ?    # Apply all three conditions

print(f"Number of young first-class female passengers: {len(filtered_passengers)}")
print("\nFirst few:")
filtered_passengers[['Name', 'Age', 'Pclass', 'Sex']].head()

# %% [markdown]
# ### Task 12: Missing Data Analysis
#
# Check for missing data in the Titanic dataset:
# 1. Count how many missing values are in each column
# 2. Calculate the percentage of missing values for the 'Age' column
#
# **Hints:**
# - Use `.isnull()` to create a boolean mask of missing values
# - Use `.sum()` to count True values
# - Apply to each column with `.isnull().sum()`

# %%
# Task 12: Write your code here
missing_counts = ?             # Count missing values per column
age_missing_percent = ?        # Calculate percentage for Age column

print("Missing values per column:")
print(missing_counts)
print(f"\nPercentage of missing Age values: {age_missing_percent:.1f}%")

# %% [markdown]
# ---
# ## Summary
#
# Congratulations! You've completed the introduction to NumPy and Pandas.
#
# **You now know:**
#
# **NumPy:**
# - Creating and manipulating arrays
# - Mathematical operations and broadcasting
# - Random number generation
# - Array statistics and reshaping
#
# **Pandas:**
# - Creating and loading DataFrames
# - Viewing and selecting data
# - Filtering with boolean conditions
# - Creating new columns
# - Grouping and aggregation
# - Handling missing data
#
# These are the foundational tools for machine learning! Next, you'll dive deeper into data preprocessing, visualization, and ML algorithms.
#
# ### What's Next?
#
# Continue with:
# - `01_NumPyIntro.ipynb` - Deeper dive into NumPy
# - `02_PandasIntro.ipynb` - More Pandas features
# - `03_Data_Preprocessing.ipynb` - Preparing data for ML
# - `Data_Visualization_Demo_With_Seaborn.ipynb` - Creating plots and charts
